# %% [markdown]
# # Visualization of progression Graph (in R)
# (https://sites.google.com/site/centretranslationinnovation/tpr-db/visualization-in-r)
# - read the source file (progGra.R, or app.R)
#     - two functions:
#     - ReadData(<filename>) : reads data to
#     - ProgGraph() : plot the progression graph
# - read data from a session
# - vizualize the data with a progression graph
# - modify settings

# %%
# read the R core  with the functions
source("/data/critt/shiny-server/mcarl6/Annotate/app.R")

# this reads a default session
# Out:
# hash-2.2.6.2 provided by Decision Patterns
# Reading Keyboard data: /data/critt/tprdb/TPRDB/AR20/Tables/P02_T3 .kd
# Reading Fixation data: /data/critt/tprdb/TPRDB/AR20/Tables/P02_T3 .fd
# Reading Fixation Units: /data/critt/tprdb/TPRDB/AR20/Tables/P02_T3 .fu
# Reading Production Units: /data/critt/tprdb/TPRDB/AR20/Tables/P02_T3 .pu
# Reading Activity Units: /data/critt/tprdb/TPRDB/AR20/Tables/P02_T3 .au
# Reading Source Text: /data/critt/tprdb/TPRDB/AR20/Tables/P02_T3 .st

# %%
# read the session that we want to vizualize
ReadData("/data/critt/tprdb/TPRDB/BML12/Tables/P06_T5")
# Out:
# Reading Keyboard data: /data/critt/tprdb/TPRDB/BML12/Tables/P06_T5 .kd
# Reading Fixation data: /data/critt/tprdb/TPRDB/BML12/Tables/P06_T5 .fd
# Reading Fixation Units: /data/critt/tprdb/TPRDB/BML12/Tables/P06_T5 .fu
# Reading Production Units: /data/critt/tprdb/TPRDB/BML12/Tables/P06_T5 .pu
# Reading Activity Units: /data/critt/tprdb/TPRDB/BML12/Tables/P06_T5 .au
# Reading Source Text: /data/critt/tprdb/TPRDB/BML12/Tables/P06_T5 .st

# %%
# plot a view of the entire session
ProgGraph()
# Out:
# plot without title

# %%
# zoom into the session, select a time window 
ProgGraph(X1=30000, X2=80000)
# Out:
# plot without title

# %%
# zoom into the session, select a time window (X) and a text window (Y) 
ProgGraph(X1 = 45000, X2 =55000, Y1=24, Y2=35)
# Out:
# plot without title

# %%
# visualise production unit (pu=1)
ProgGraph(X1 = 45000, X2 =55000, Y1=24, Y2=35, pu=1, fu=1)
# Out:
# plot without title

# %%
# zoom further into the segment, visualise production units and fixation units 
ProgGraph(X1 = 45000, X2 =55000, Y1=24, Y2=35, pu=1, fu=1, au=1, auLines = 1, seg = 0, label = 0)
# Out:
# plot without title
